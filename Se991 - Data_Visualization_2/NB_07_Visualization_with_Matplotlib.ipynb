# %% [markdown]
# # Part 1: Pandas - from Zero to Hero

# %% [markdown]
# ## Data Visualization with Matplotlib

# %% [markdown]
# ### The plot() method

# %%
import pandas as pd

# %%
titanic = pd.read_csv(r"C:\Users\palab\Data_Analyst_Course_6_365_Careers\Se11 - Files_Alexandar\titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
import matplotlib.pyplot as plt

# %%
titanic.plot(subplots= True, figsize=(15, 12), sharex= False, sharey=False)
plt.show()

# %%
titanic.age.plot(figsize=(12, 8))
plt.show()

# %% [markdown]
# ### Customization of plots

# %%
xticks = [x for x in range(0,901, 50)]
xticks
# Out:
# [0,
#  50,
#  100,
#  150,
#  200,
#  250,
#  300,
#  350,
#  400,
#  450,
#  500,
#  550,
#  600,
#  650,
#  700,
#  750,
#  800,
#  850,
#  900]

# %%
yticks = [y for y in range(0, 81, 5)]
yticks
# Out:
# [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80]

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("classic")

# %%
titanic.age.plot(figsize = (12,8), fontsize= 13, c = "gray", linestyle = "-",
                 xlim = (0,900), ylim = (0,80), xticks = xticks, yticks = yticks, rot = 45) 
plt.title("Titanic - Ages", fontsize = 15)
plt.legend(loc = 3, fontsize = 15)
plt.xlabel("Passenger No", fontsize = 13)
plt.ylabel("Age", fontsize = 13)
plt.grid()
plt.show()

# %% [markdown]
# ### Histograms

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
titanic = pd.read_csv(r"C:\Users\palab\Data_Analyst_Course_6_365_Careers\Se11 - Files_Alexandar\titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.age.value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
#          ..
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: age, Length: 88, dtype: int64

# %%
titanic.age.plot(kind = "hist", figsize = (12,8), fontsize = 15, bins = 80, density = True)
plt.show()

# %%
titanic.age.hist(figsize = (12,8), bins = 80, xlabelsize=15, ylabelsize= 15, cumulative = True)
plt.show()

# %%
plt.figure(figsize = (12,8))
plt.hist(titanic.age.dropna(), bins = 80, density = True, cumulative= True)
plt.show()

# %% [markdown]
# ### Barcharts and Piecharts

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
summer_2012 = pd.read_csv(r"C:\Users\palab\Data_Analyst_Course_6_365_Careers\Se11 - Files_Alexandar\summer_2012.csv", index_col = "Country")

# %%
summer_2012
# Out:
#          Medal
# Country
# USA        250
# RUS        130
# CHN        128
# GBR        126
# AUS        114
# GER         94
# JPN         84
# FRA         82
# NED         69
# ITA         68
# ESP         65
# KOR         63
# BRA         59
# CAN         57
# CRO         35
# HUN         26
# MEX         26
# NZL         26
# JAM         25
# UKR         25
# Others     393

# %%
summer_2012.Medal.sort_values(ascending=False).plot(kind = "bar", figsize = (12,8), fontsize = 12)
plt.show()

# %%
import seaborn as sns
sns.set_palette('Set1')
summer_2012.Medal.plot(kind = "pie", figsize = (12,8), fontsize = 12,rot=45)
plt.show()

# %% [markdown]
# ### Scatterplots

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
titanic = pd.read_csv(r"C:\Users\palab\Data_Analyst_Course_6_365_Careers\Se11 - Files_Alexandar\titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.plot(kind = "scatter", figsize = (15,8), x = "age", y = "fare", c = "pclass", marker = "x", s = 20, colormap= "viridis" ,colorbar=True) 
plt.show()
