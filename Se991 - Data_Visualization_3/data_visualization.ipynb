# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib

# %%
transactions=pd.read_csv(r"C:\Users\palab\Data_Analyst_Course_6_365_Careers\Se11 - Files_Maven_Analytics\retail\transactions.csv",parse_dates=["date"])
transactions.head()
# Out:
#         date  store_nbr  transactions
# 0 2013-01-01         25           770
# 1 2013-01-02          1          2111
# 2 2013-01-02          2          2358
# 3 2013-01-02          3          3487
# 4 2013-01-02          4          1922

# %%
transactions.plot()
# Out:
# <AxesSubplot:>

# %%
transactions.plot();

# %%
transactions.set_index("date")
# Out:
#             store_nbr  transactions
# date
# 2013-01-01         25           770
# 2013-01-02          1          2111
# 2013-01-02          2          2358
# 2013-01-02          3          3487
# 2013-01-02          4          1922
# ...               ...           ...
# 2017-08-15         50          2804
# 2017-08-15         51          1573
# 2017-08-15         52          2255
# 2017-08-15         53           932
# 2017-08-15         54           802
#
# [83488 rows x 2 columns]

# %%
transactions.set_index("date").loc["2013-01","transactions"]
# Out:
# date
# 2013-01-01     770
# 2013-01-02    2111
# 2013-01-02    2358
# 2013-01-02    3487
# 2013-01-02    1922
#               ...
# 2013-01-31    2432
# 2013-01-31    1573
# 2013-01-31    2153
# 2013-01-31    1524
# 2013-01-31     714
# Name: transactions, Length: 1381, dtype: int64

# %%
transactions.set_index("date").loc["2013-01","transactions"].plot();

# %%
transactions.query(
    "store_nbr==44").set_index("date").loc[
    "2013-01","transactions"]
# Out:
# date
# 2013-01-02    4821
# 2013-01-03    3618
# 2013-01-04    4169
# 2013-01-05    4921
# 2013-01-06    4925
# 2013-01-07    3871
# 2013-01-08    3593
# 2013-01-09    4006
# 2013-01-10    3323
# 2013-01-11    3873
# 2013-01-12    4423
# 2013-01-13    4676
# 2013-01-14    3450
# 2013-01-15    3527
# 2013-01-16    4026
# 2013-01-17    3412
# 2013-01-18    3801
# 2013-01-19    4656
# 2013-01-20    4732
# 2013-01-21    3508
# 2013-01-22    3349
# 2013-01-23    3704
# 2013-01-24    3121
# 2013-01-25    3751
# 2013-01-26    4812
# 2013-01-27    4648
# 2013-01-28    3392
# 2013-01-29    3317
# 2013-01-30    3852
# 2013-01-31    3509
# Name: transactions, dtype: int64

# %%
transactions.query(
    "store_nbr==44").set_index("date").loc[
    "2013-01","transactions"].plot();

# %%
transactions_44=transactions.loc[
    transactions["store_nbr"]==44,["date","transactions"]]
transactions_44
# Out:
#             date  transactions
# 38    2013-01-02          4821
# 84    2013-01-03          3618
# 130   2013-01-04          4169
# 176   2013-01-05          4921
# 222   2013-01-06          4925
# ...          ...           ...
# 83261 2017-08-11          4418
# 83315 2017-08-12          4277
# 83369 2017-08-13          4392
# 83423 2017-08-14          4039
# 83477 2017-08-15          3815
#
# [1677 rows x 2 columns]

# %%
transactions_44.set_index("date").plot();

# %%
transactions_44.plot(x="date",y="transactions");

# %%
(transactions.query("store_nbr in [44,47]")\
.pivot_table(index="date",columns="store_nbr")\
.droplevel(0,axis=1)\
.plot());

# %% [markdown]
# #### seaborn style

# %%
sns.set_style("darkgrid")

# %%
transactions_44.set_index("date").loc["2013-01"].plot(
title="Store 44 Transaction 2013-2017",
xlabel="Date",
ylabel="Daily of Transactions",
legend=False,
color="blue",
alpha=0.9,
style="--"
).legend(loc="upper center");

# %% [markdown]
# #### Matplotlib style

# %%
matplotlib.style.use("fivethirtyeight")

# %%
transactions_44.set_index("date").loc["2013-01"].plot(
title="Store 44 Transaction 2013-2017",
xlabel="Date",
ylabel="Daily of Transactions",
#legend=False,
#color="Black",
#alpha=0.5,
grid=True,
#style="--"
).legend(bbox_to_anchor=[1.31,1]);

# %%
transactions.loc[transactions["store_nbr"].isin([44,47])].pivot(
    index="date",columns="store_nbr").plot(
color=["Blue","Red"],linewidth=1);

# %%
transactions.loc[transactions["store_nbr"].isin([44,47])].pivot(
    index="date",columns="store_nbr").plot(
color=["#FB0909","Green"]);

# %%
transactions.loc[transactions["store_nbr"].isin([44,47])].pivot(
    index="date",columns="store_nbr").plot(
color=["k","g"]);

# %%
transactions.loc[transactions["store_nbr"].isin([44,47])].pivot(
    index="date",columns="store_nbr").plot(
cmap="Pastel1");

# %%
transactions.loc[transactions["store_nbr"].isin([44,47])].pivot(
    index="date",columns="store_nbr").plot(
cmap="Pastel2");

# %%
transactions.loc[transactions["store_nbr"].isin([44,47])].pivot(
    index="date",columns="store_nbr").plot(
cmap="Pastel2",
subplots=True);

# %%
transactions.loc[transactions["store_nbr"].isin([44,47])].pivot(
    index="date",columns="store_nbr").plot(
cmap="Pastel2",
subplots=True,
layout=[1,2],
sharey=True,
title=["store_44","store_47"]);

# %%
transactions.loc[transactions["store_nbr"].isin([44,47])].pivot(
    index="date",columns="store_nbr").plot(
legend=False,
figsize=[8,4],
cmap="Pastel2",
subplots=True,
layout=[1,2],
sharey=True,
title=["store_44","store_47"]);

# %%
transactions[transactions["store_nbr"].isin(
    [1,2,3,4,5])].iloc[:50,:].pivot(
    index="date",columns="store_nbr").droplevel(0,axis=1)
# Out:
# store_nbr      1     2     3     4     5
# date
# 2013-01-02  2111  2358  3487  1922  1903
# 2013-01-03  1833  2033  3026  1551  1740
# 2013-01-04  1863  2066  3188  1596  1642
# 2013-01-05  1509  2062  3623  1825  1643
# 2013-01-06   520  1992  3590  1891  1754
# 2013-01-07  1807  1911  2996  1514  1577
# 2013-01-08  1869  1856  2826  1397  1504
# 2013-01-09  1910  1975  2932  1533  1513
# 2013-01-10  1679  1761  2649  1326  1449
# 2013-01-11  1813  1786  2954  1398  1446

# %%
transactions[transactions["store_nbr"].isin(
    [1,2,3,4,5])].iloc[:50,:].pivot(
    index="date",columns="store_nbr").droplevel(0,axis=1).plot(kind="bar");

# %%
transactions[transactions["store_nbr"].isin(
    [1,2,3,4,5])].iloc[:50,:].pivot(
    index="date",columns="store_nbr").droplevel(0,axis=1).plot.bar(rot=45)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
transactions[transactions["store_nbr"].isin(
    [1,2,3,4,5])].iloc[:20,:].pivot(
    index="date",columns="store_nbr").droplevel(0,axis=1).plot.bar(
stacked=True,rot=45).legend(bbox_to_anchor=[1.2,1]);

# %%
(transactions[transactions["store_nbr"].isin(
    [1,2,3,4,5])].iloc[:20,:].pivot(
    index="date",columns="store_nbr").droplevel(0,axis=1).plot.bar(
stacked=True,rot=45,legend=False).set_xticklabels(
labels=["2nd Jan","3rd Jan","4th Jan","5th Jan"]));

# %%
transactions.query(
    "store_nbr in [1,2,3,4,5] and date.dt.month in [1,2,3]").pivot_table(
    index=transactions["date"].dt.month,columns=transactions["store_nbr"],values="transactions",aggfunc="sum").plot.bar(
).legend(bbox_to_anchor=[1,1]);

# %%
transactions.query(
    "store_nbr in [1,2,3,4,5] and date.dt.month in [1,2,3]").pivot_table(
    index=transactions["date"].dt.month,columns=transactions["store_nbr"],values="transactions",aggfunc="sum").plot.bar(
stacked=True).legend(bbox_to_anchor=[1,1]);

# %%
transactions.query(
    "store_nbr in [1,2,3,4,5] and date.dt.month in [1,2,3]").pivot_table(
    index=transactions["date"].dt.month,columns=transactions["store_nbr"],values="transactions",aggfunc="sum").plot.barh(
stacked=True).legend(bbox_to_anchor=[1,1]);

# %%
(transactions.query(
    "store_nbr in [1,2,3,4,5] and date.dt.month in [1,2,3]").pivot_table(
    index=transactions["date"].dt.month,columns=transactions["store_nbr"],values="transactions",aggfunc="sum"
).apply(lambda x : (x/sum(x))*100,axis=1));

# %%
transactions.query(
    "store_nbr in [1,2,3,4,5] and date.dt.month in [1,2,3]").pivot_table(
    index=transactions["date"].dt.month,columns=transactions["store_nbr"],values="transactions",aggfunc="sum"
).apply(lambda x : x*100/sum(x),axis=1).plot.barh(
stacked=True).legend(bbox_to_anchor=[1,1]);

# %%
stacked_data=(transactions[transactions["store_nbr"].isin(
    [1,2,3,4,5])].iloc[:20,:].pivot(
    index="date",columns="store_nbr").droplevel(0,axis=1))\
.apply(lambda x: round(x*100/sum(x),2),axis=1)

stacked_data
# Out:
# store_nbr       1      2      3      4      5
# date
# 2013-01-02  17.92  20.02  29.60  16.31  16.15
# 2013-01-03  18.00  19.96  29.72  15.23  17.09
# 2013-01-04  17.99  19.95  30.79  15.41  15.86
# 2013-01-05  14.15  19.34  33.98  17.12  15.41

# %%
stacked_data.plot.bar(stacked=True,legend=False);

# %%
transactions[transactions["store_nbr"].isin(
    [1,2,3,4,5])].iloc[:50,:].pivot(
    index="date",columns="store_nbr").droplevel(0,axis=1).plot.barh(rot=45)
# Out:
# <AxesSubplot:ylabel='date'>

# %%
transactions
# Out:
#             date  store_nbr  transactions
# 0     2013-01-01         25           770
# 1     2013-01-02          1          2111
# 2     2013-01-02          2          2358
# 3     2013-01-02          3          3487
# 4     2013-01-02          4          1922
# ...          ...        ...           ...
# 83483 2017-08-15         50          2804
# 83484 2017-08-15         51          1573
# 83485 2017-08-15         52          2255
# 83486 2017-08-15         53           932
# 83487 2017-08-15         54           802
#
# [83488 rows x 3 columns]

# %%
transactions.groupby(["store_nbr"]).agg({"transactions":"sum"}).sort_values(
    by="transactions",ascending=False).iloc[:10]
# Out:
#            transactions
# store_nbr
# 44              7273093
# 47              6535810
# 45              6201115
# 46              5990113
# 3               5366350
# 48              5107785
# 8               4637971
# 49              4574103
# 50              4384444
# 11              3972488

# %%
transactions.groupby(["store_nbr"]).agg({"transactions":"sum"}).sort_values(
    by="transactions",ascending=True).iloc[:10].plot.barh(legend=False);

# %%
transactions.groupby(["store_nbr"]).agg({"transactions":"sum"}).sort_values(
    by="transactions",ascending=True).plot.bar(rot=45,legend=False,figsize=(16,10));

# %%
store_40s=list(range(40,50))
transactions.query("store_nbr in @store_40s").groupby(
    ["store_nbr"]).agg({"transactions":"sum"}).sort_values(
    by="transactions",ascending=True).plot(kind='bar',
    rot=45,legend=False,figsize=(10,10));

# %%
store_40s=list(range(40,50))
transactions.query("store_nbr in @store_40s").groupby(
    ["store_nbr"]).agg({"transactions":"sum"}).sort_values(
    by="transactions",ascending=True).plot.barh(
    rot=45,legend=False,figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='store_nbr'>

# %%
t1=transactions.query("store_nbr in [1,2,3,4]").pivot_table(index=transactions["date"].astype("Datetime64"),
                        columns="store_nbr",
                        values="transactions",
                        aggfunc="sum")
t1.groupby(t1.index.month).sum()
# Out:
# store_nbr         1         2         3         4
# date
# 1          229203.0  284134.0  463260.0  222075.0
# 2          209400.0  265922.0  437238.0  209211.0
# 3          232178.0  293076.0  487224.0  231837.0
# 4          229081.0  287325.0  478308.0  223928.0
# 5          231160.0  293588.0  491961.0  228753.0
# 6          231514.0  284835.0  474668.0  222678.0
# 7          236032.0  288783.0  484698.0  224327.0
# 8          202821.0  255475.0  431752.0  200100.0
# 9          182035.0  228658.0  379101.0  178172.0
# 10         184419.0  232326.0  387766.0  181158.0
# 11         175957.0  227973.0  379532.0  175753.0
# 12         210163.0  277806.0  470842.0  221015.0

# %%
t1.groupby(t1.index.month).sum().plot(kind='pie',subplots=True,legend=False,figsize=(12,8));

# %%
transactions.loc[:100,:].plot.scatter(x="store_nbr",y="transactions")
# Out:
# <AxesSubplot:xlabel='store_nbr', ylabel='transactions'>

# %%
transactions.loc[:100,:].plot.scatter(x="store_nbr",y="transactions",
                                     colormap="Set2")
# Out:
# <AxesSubplot:xlabel='store_nbr', ylabel='transactions'>

# %%
(transactions
 .query(
    "store_nbr in @store_40s and date.dt.month in [1,2,3]")
 .groupby("store_nbr").agg({"transactions":"sum"})
)
# Out:
#            transactions
# store_nbr
# 40               564515
# 41               448122
# 42               194871
# 43               579435
# 44              1868114
# 45              1610965
# 46              1556157
# 47              1702525
# 48              1321544
# 49              1156066

# %%
(transactions
 .query(
    "store_nbr in @store_40s and date.dt.month in [1,2,3]")
 .groupby("store_nbr").agg({"transactions":"sum"})
).plot.pie(y="transactions").legend(bbox_to_anchor=[1,1])

# %%
(transactions.query("store_nbr in @store_40s").pivot_table(
    index=transactions["date"].dt.month,
                        columns="store_nbr",
                        values="transactions",
                        aggfunc="sum")
)
t1.groupby(t1.index.month).sum()
# Out:
# store_nbr         1         2         3         4
# date
# 1          229203.0  284134.0  463260.0  222075.0
# 2          209400.0  265922.0  437238.0  209211.0
# 3          232178.0  293076.0  487224.0  231837.0
# 4          229081.0  287325.0  478308.0  223928.0
# 5          231160.0  293588.0  491961.0  228753.0
# 6          231514.0  284835.0  474668.0  222678.0
# 7          236032.0  288783.0  484698.0  224327.0
# 8          202821.0  255475.0  431752.0  200100.0
# 9          182035.0  228658.0  379101.0  178172.0
# 10         184419.0  232326.0  387766.0  181158.0
# 11         175957.0  227973.0  379532.0  175753.0
# 12         210163.0  277806.0  470842.0  221015.0

# %%
(transactions.query("store_nbr in @store_40s").pivot_table(
    index=transactions["date"].dt.month,
                        columns="store_nbr",
                        values="transactions",
                        aggfunc="sum")
).plot.scatter(x=44,y=47)
#t1.groupby(t1.index.month).sum()
# Out:
# <AxesSubplot:xlabel='44', ylabel='47'>

# %%
transactions["transactions"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
transactions.loc[transactions["store_nbr"]==47,"transactions"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>
