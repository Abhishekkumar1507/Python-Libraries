# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## pd arguments

# %%
n=[]
for i in sorted(dir(pd)):
    if i.startswith("_") or i.startswith("__"):
        continue
    else:
        print(i.ljust(15),end=" ")
        n.append(i)
print("\n")
print(len(n))
# Out:
# BooleanDtype    Categorical     CategoricalDtype CategoricalIndex DataFrame       DateOffset      DatetimeIndex   DatetimeTZDtype ExcelFile       ExcelWriter     Float64Index    Grouper         HDFStore        Index           IndexSlice      Int16Dtype      Int32Dtype      Int64Dtype      Int64Index      Int8Dtype       Interval        IntervalDtype   IntervalIndex   MultiIndex      NA              NaT             NamedAgg        Period          PeriodDtype     PeriodIndex     RangeIndex      Series          SparseDtype     StringDtype     Timedelta       TimedeltaIndex  Timestamp       UInt16Dtype     UInt32Dtype     UInt64Dtype     UInt64Index     UInt8Dtype      api             array           arrays          bdate_range     compat          concat          core            crosstab        cut             date_range      describe_option errors          eval            factorize       get_dummies     get_option      infer_freq      interval_range  io              isna            isnu
# ...

# %% [markdown]
# ## pd.DataFrame arguments

# %%
b=['data','index','columns','dtype','type','copy']
for i in b:
    print(i,end="    ")
# Out:
# data    index    columns    dtype    type    copy

# %% [markdown]
# ## pd.DataFrame Directory

# %%
k=[]
for i in sorted(dir(pd.DataFrame)):
    if i.startswith("_") or i.startswith("__"):
        continue
    else:
        print(i.ljust(15),end=" ")
        k.append(i)
print("\n")
print(len(k))
# Out:
# T               abs             add             add_prefix      add_suffix      agg             aggregate       align           all             any             append          apply           applymap        asfreq          asof            assign          astype          at              at_time         attrs           axes            backfill        between_time    bfill           bool            boxplot         clip            columns         combine         combine_first   compare         convert_dtypes  copy            corr            corrwith        count           cov             cummax          cummin          cumprod         cumsum          describe        diff            div             divide          dot             drop            drop_duplicates droplevel       dropna          dtypes          duplicated      empty           eq              equals          eval            ewm             expanding       explode         ffill           fillna          filter          first 
# ...

# %%
df=pd.read_csv("Sales_short_data2.csv")
df
# Out:
#          Dates      Customer Name    Sales  Quantity  Discount   Profit
# 0   17-04-2022         Anne Pryor   18.690         7       0.0   5.2332
# 1   18-04-2022        Mark Packer  140.750         5       0.0  42.2250
# 2   19-04-2022      Ashley Jarboe    9.344         2       0.2   1.8688
# 3   20-04-2022       Noel Staavos   11.200         7       0.0   4.8160
# 4   21-04-2022        Vivek Grady    8.940         3       0.0   2.4138
# 5   22-04-2022      Mark Hamilton   19.152         2       0.2   1.1970
# 6   23-04-2022    Brosina Hoffman    7.280         4       0.0   1.9656
# 7   24-04-2022       Edward Hooks   39.680         2       0.0  16.2688
# 8   25-04-2022         Dan Lawera    5.760         2       0.0   1.6704
# 9   26-04-2022    Andrew Gjertsen    4.448         2       0.2   0.3336
# 10  27-04-2022  Cassandra Brandow   34.650         3       0.0   9.7020
# 11  28-04-2022     Troy Blackwell  120.768         4       0.2   9.0576
# ...

# %%
df.T
# Out:
#                        0            1              2             3   \
# Dates          17-04-2022   18-04-2022     19-04-2022    20-04-2022
# Customer Name  Anne Pryor  Mark Packer  Ashley Jarboe  Noel Staavos
# Sales               18.69       140.75          9.344          11.2
# Quantity                7            5              2             7
# Discount                0            0            0.2             0
# Profit             5.2332       42.225         1.8688         4.816
#
#                         4              5                6             7   \
# Dates           21-04-2022     22-04-2022       23-04-2022    24-04-2022
# Customer Name  Vivek Grady  Mark Hamilton  Brosina Hoffman  Edward Hooks
# Sales                 8.94         19.152             7.28         39.68
# Quantity                 3              2                4             2
# Discount                 0            0.2                0             0
# ...

# %%
df.transpose()
# Out:
#                        0            1              2             3   \
# Dates          17-04-2022   18-04-2022     19-04-2022    20-04-2022
# Customer Name  Anne Pryor  Mark Packer  Ashley Jarboe  Noel Staavos
# Sales               18.69       140.75          9.344          11.2
# Quantity                7            5              2             7
# Discount                0            0            0.2             0
# Profit             5.2332       42.225         1.8688         4.816
#
#                         4              5                6             7   \
# Dates           21-04-2022     22-04-2022       23-04-2022    24-04-2022
# Customer Name  Vivek Grady  Mark Hamilton  Brosina Hoffman  Edward Hooks
# Sales                 8.94         19.152             7.28         39.68
# Quantity                 3              2                4             2
# Discount                 0            0.2                0             0
# ...

# %%
df.abs
# Out:
# <bound method NDFrame.abs of          Dates      Customer Name    Sales  Quantity  Discount   Profit
# 0   17-04-2022         Anne Pryor   18.690         7       0.0   5.2332
# 1   18-04-2022        Mark Packer  140.750         5       0.0  42.2250
# 2   19-04-2022      Ashley Jarboe    9.344         2       0.2   1.8688
# 3   20-04-2022       Noel Staavos   11.200         7       0.0   4.8160
# 4   21-04-2022        Vivek Grady    8.940         3       0.0   2.4138
# 5   22-04-2022      Mark Hamilton   19.152         2       0.2   1.1970
# 6   23-04-2022    Brosina Hoffman    7.280         4       0.0   1.9656
# 7   24-04-2022       Edward Hooks   39.680         2       0.0  16.2688
# 8   25-04-2022         Dan Lawera    5.760         2       0.0   1.6704
# 9   26-04-2022    Andrew Gjertsen    4.448         2       0.2   0.3336
# 10  27-04-2022  Cassandra Brandow   34.650         3       0.0   9.7020
# 11  28-04-2022     Troy Blackwell  120.768         4       0.2   9.0576
# ...

# %%
df.bool
# Out:
# <bound method NDFrame.bool of          Dates      Customer Name    Sales  Quantity  Discount   Profit
# 0   17-04-2022         Anne Pryor   18.690         7       0.0   5.2332
# 1   18-04-2022        Mark Packer  140.750         5       0.0  42.2250
# 2   19-04-2022      Ashley Jarboe    9.344         2       0.2   1.8688
# 3   20-04-2022       Noel Staavos   11.200         7       0.0   4.8160
# 4   21-04-2022        Vivek Grady    8.940         3       0.0   2.4138
# 5   22-04-2022      Mark Hamilton   19.152         2       0.2   1.1970
# 6   23-04-2022    Brosina Hoffman    7.280         4       0.0   1.9656
# 7   24-04-2022       Edward Hooks   39.680         2       0.0  16.2688
# 8   25-04-2022         Dan Lawera    5.760         2       0.0   1.6704
# 9   26-04-2022    Andrew Gjertsen    4.448         2       0.2   0.3336
# 10  27-04-2022  Cassandra Brandow   34.650         3       0.0   9.7020
# 11  28-04-2022     Troy Blackwell  120.768         4       0.2   9.0576
# ...

# %%
df.columns
# Out:
# Index(['Dates', 'Customer Name', 'Sales', 'Quantity', 'Discount', 'Profit'], dtype='object')

# %%
print(type(df.columns))
# Out:
# <class 'pandas.core.indexes.base.Index'>

# %%
print(type(df.columns[0]))
# Out:
# <class 'str'>

# %%
print(df.columns[0])
# Out:
# Dates

# %%
for i in range(len(df.columns)):
    print(df.columns[i])
# Out:
# Dates
# Customer Name
# Sales
# Quantity
# Discount
# Profit

# %%
df.dtypes
# Out:
# Dates             object
# Customer Name     object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df.head()
# Out:
#         Dates  Customer Name    Sales  Quantity  Discount   Profit
# 0  17-04-2022     Anne Pryor   18.690         7       0.0   5.2332
# 1  18-04-2022    Mark Packer  140.750         5       0.0  42.2250
# 2  19-04-2022  Ashley Jarboe    9.344         2       0.2   1.8688
# 3  20-04-2022   Noel Staavos   11.200         7       0.0   4.8160
# 4  21-04-2022    Vivek Grady    8.940         3       0.0   2.4138

# %%
df.describe()
# Out:
#             Sales   Quantity   Discount     Profit
# count   13.000000  13.000000  13.000000  13.000000
# mean    33.156154   3.461538   0.076923   7.562077
# std     44.815869   1.853617   0.101274  11.368465
# min      4.448000   2.000000   0.000000   0.333600
# 25%      8.940000   2.000000   0.000000   1.670400
# 50%     11.200000   3.000000   0.000000   2.413800
# 75%     34.650000   4.000000   0.200000   9.057600
# max    140.750000   7.000000   0.200000  42.225000

# %%
df['Sales'].min()
# Out:
# 4.448

# %%
df['Quantity'].max()
# Out:
# 7

# %%
df['Quantity'].mode()
# Out:
# 0    2
# dtype: int64

# %%
df['Profit'].mean()
# Out:
# 7.562076923076924

# %%
df['Sales'].median()
# Out:
# 11.2

# %%
df['Profit'].sum()
# Out:
# 98.307

# %%
df.ndim
# Out:
# 2

# %%
df.isnull()
# Out:
#     Dates  Customer Name  Sales  Quantity  Discount  Profit
# 0   False          False  False     False     False   False
# 1   False          False  False     False     False   False
# 2   False          False  False     False     False   False
# 3   False          False  False     False     False   False
# 4   False          False  False     False     False   False
# 5   False          False  False     False     False   False
# 6   False          False  False     False     False   False
# 7   False          False  False     False     False   False
# 8   False          False  False     False     False   False
# 9   False          False  False     False     False   False
# 10  False          False  False     False     False   False
# 11  False          False  False     False     False   False
# 12  False          False  False     False     False   False

# %%
df.notnull()
# Out:
#     Dates  Customer Name  Sales  Quantity  Discount  Profit
# 0    True           True   True      True      True    True
# 1    True           True   True      True      True    True
# 2    True           True   True      True      True    True
# 3    True           True   True      True      True    True
# 4    True           True   True      True      True    True
# 5    True           True   True      True      True    True
# 6    True           True   True      True      True    True
# 7    True           True   True      True      True    True
# 8    True           True   True      True      True    True
# 9    True           True   True      True      True    True
# 10   True           True   True      True      True    True
# 11   True           True   True      True      True    True
# 12   True           True   True      True      True    True

# %%
df.isnull().sum()
# Out:
# Dates            0
# Customer Name    0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Dates            13
# Customer Name    13
# Sales            13
# Quantity         13
# Discount         13
# Profit           13
# dtype: int64

# %% [markdown]
# # pd.read_csv() arguments

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer: Union[str, pathlib.Path, IO[~AnyStr]], sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal: str = '.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
# ...

# %%
a="filepath_or_buffer: Union[str, pathlib.Path, IO[~AnyStr]], sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal: str = '.', lineterminator=None, quotechar=, quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None"

m=[]

for i in range(len(a)):
    if a[i]!="=":
        continue
    elif a[i]=="=":
        f=i
        while a[f]!=" ":
            k=f
            f-=1
            #print(k)
    m.append(a[k:i])
#print(m)
#
print()
#print(len(m))
for i in sorted(m):
    print(i.ljust(20),end="  ")
# Out:
#                       cache_dates           chunksize             comment               compression           converters            date_parser           dayfirst              delim_whitespace      delimiter             dialect               doublequote           dtype                 encoding              engine                error_bad_lines       escapechar            false_values          float_precision       header                index_col             infer_datetime_format  iterator              keep_date_col         keep_default_na       lineterminator        low_memory            mangle_dupe_cols      memory_map            na_filter             na_values             names                 nrows                 parse_dates           prefix                quotechar             quoting               sep                   skip_blank_lines      skipfooter            skipinitialspace      skiprows              squeeze               thousands             true_values           usecols
# ...

# %% [markdown]
# ## pd.read_csv Directory

# %%
k=[]
for i in sorted(dir(pd.read_csv)):
    if i.startswith("_") or i.startswith("__"):
        continue
    else:
        #print(i.ljust(15),end=" ")
        k.append(i)
print("\n")
print(len(k))
# Out:
# 0

# %%
df=pd.read_csv("Sales_short_data2.csv")

# %%
df
# Out:
#          Dates      Customer Name    Sales  Quantity  Discount   Profit
# 0   17-04-2022         Anne Pryor   18.690         7       0.0   5.2332
# 1   18-04-2022        Mark Packer  140.750         5       0.0  42.2250
# 2   19-04-2022      Ashley Jarboe    9.344         2       0.2   1.8688
# 3   20-04-2022       Noel Staavos   11.200         7       0.0   4.8160
# 4   21-04-2022        Vivek Grady    8.940         3       0.0   2.4138
# 5   22-04-2022      Mark Hamilton   19.152         2       0.2   1.1970
# 6   23-04-2022    Brosina Hoffman    7.280         4       0.0   1.9656
# 7   24-04-2022       Edward Hooks   39.680         2       0.0  16.2688
# 8   25-04-2022         Dan Lawera    5.760         2       0.0   1.6704
# 9   26-04-2022    Andrew Gjertsen    4.448         2       0.2   0.3336
# 10  27-04-2022  Cassandra Brandow   34.650         3       0.0   9.7020
# 11  28-04-2022     Troy Blackwell  120.768         4       0.2   9.0576
# ...

# %%
df=pd.read_csv("Sales_short_data2.csv",dtype={'Sales':np.float32,'Quantity':np.float64,'Profit':np.float32})
df
# Out:
#          Dates      Customer Name       Sales  Quantity  Discount     Profit
# 0   17-04-2022         Anne Pryor   18.690001       7.0       0.0   5.233200
# 1   18-04-2022        Mark Packer  140.750000       5.0       0.0  42.224998
# 2   19-04-2022      Ashley Jarboe    9.344000       2.0       0.2   1.868800
# 3   20-04-2022       Noel Staavos   11.200000       7.0       0.0   4.816000
# 4   21-04-2022        Vivek Grady    8.940000       3.0       0.0   2.413800
# 5   22-04-2022      Mark Hamilton   19.152000       2.0       0.2   1.197000
# 6   23-04-2022    Brosina Hoffman    7.280000       4.0       0.0   1.965600
# 7   24-04-2022       Edward Hooks   39.680000       2.0       0.0  16.268801
# 8   25-04-2022         Dan Lawera    5.760000       2.0       0.0   1.670400
# 9   26-04-2022    Andrew Gjertsen    4.448000       2.0       0.2   0.333600
# 10  27-04-2022  Cassandra Brandow   34.650002       3.0       0.0   9.702000
# ...

# %%
df=pd.read_csv("Sales_short_data2.csv",encoding='utf-8')
df
# Out:
#          Dates      Customer Name    Sales  Quantity  Discount   Profit
# 0   17-04-2022         Anne Pryor   18.690         7       0.0   5.2332
# 1   18-04-2022        Mark Packer  140.750         5       0.0  42.2250
# 2   19-04-2022      Ashley Jarboe    9.344         2       0.2   1.8688
# 3   20-04-2022       Noel Staavos   11.200         7       0.0   4.8160
# 4   21-04-2022        Vivek Grady    8.940         3       0.0   2.4138
# 5   22-04-2022      Mark Hamilton   19.152         2       0.2   1.1970
# 6   23-04-2022    Brosina Hoffman    7.280         4       0.0   1.9656
# 7   24-04-2022       Edward Hooks   39.680         2       0.0  16.2688
# 8   25-04-2022         Dan Lawera    5.760         2       0.0   1.6704
# 9   26-04-2022    Andrew Gjertsen    4.448         2       0.2   0.3336
# 10  27-04-2022  Cassandra Brandow   34.650         3       0.0   9.7020
# 11  28-04-2022     Troy Blackwell  120.768         4       0.2   9.0576
# ...

# %%
df=pd.read_csv("Sales_short_data2.csv",nrows=5)
df
# Out:
#         Dates  Customer Name    Sales  Quantity  Discount   Profit
# 0  17-04-2022     Anne Pryor   18.690         7       0.0   5.2332
# 1  18-04-2022    Mark Packer  140.750         5       0.0  42.2250
# 2  19-04-2022  Ashley Jarboe    9.344         2       0.2   1.8688
# 3  20-04-2022   Noel Staavos   11.200         7       0.0   4.8160
# 4  21-04-2022    Vivek Grady    8.940         3       0.0   2.4138

# %%
df=pd.read_csv("Sales_short_data2.csv",header=None)
df
# Out:
#              0                  1        2         3         4        5
# 0        Dates      Customer Name    Sales  Quantity  Discount   Profit
# 1   17-04-2022         Anne Pryor    18.69         7         0   5.2332
# 2   18-04-2022        Mark Packer   140.75         5         0   42.225
# 3   19-04-2022      Ashley Jarboe    9.344         2       0.2   1.8688
# 4   20-04-2022       Noel Staavos     11.2         7         0    4.816
# 5   21-04-2022        Vivek Grady     8.94         3         0   2.4138
# 6   22-04-2022      Mark Hamilton   19.152         2       0.2    1.197
# 7   23-04-2022    Brosina Hoffman     7.28         4         0   1.9656
# 8   24-04-2022       Edward Hooks    39.68         2         0  16.2688
# 9   25-04-2022         Dan Lawera     5.76         2         0   1.6704
# 10  26-04-2022    Andrew Gjertsen    4.448         2       0.2   0.3336
# 11  27-04-2022  Cassandra Brandow    34.65         3         0    9.702
# ...

# %%
df=pd.read_csv("Sales_short_data2.csv",names=['date','customer','revanue','quantity','discount','profit'])
df
# Out:
#           date           customer  revanue  quantity  discount   profit
# 0        Dates      Customer Name    Sales  Quantity  Discount   Profit
# 1   17-04-2022         Anne Pryor    18.69         7         0   5.2332
# 2   18-04-2022        Mark Packer   140.75         5         0   42.225
# 3   19-04-2022      Ashley Jarboe    9.344         2       0.2   1.8688
# 4   20-04-2022       Noel Staavos     11.2         7         0    4.816
# 5   21-04-2022        Vivek Grady     8.94         3         0   2.4138
# 6   22-04-2022      Mark Hamilton   19.152         2       0.2    1.197
# 7   23-04-2022    Brosina Hoffman     7.28         4         0   1.9656
# 8   24-04-2022       Edward Hooks    39.68         2         0  16.2688
# 9   25-04-2022         Dan Lawera     5.76         2         0   1.6704
# 10  26-04-2022    Andrew Gjertsen    4.448         2       0.2   0.3336
# 11  27-04-2022  Cassandra Brandow    34.65         3         0    9.702
# ...

# %%
df=pd.read_csv("Sales_short_data2.csv",header=0,names=['date','customer','revanue','quantity','discount','profit'])
df
# Out:
#           date           customer  revanue  quantity  discount   profit
# 0   17-04-2022         Anne Pryor   18.690         7       0.0   5.2332
# 1   18-04-2022        Mark Packer  140.750         5       0.0  42.2250
# 2   19-04-2022      Ashley Jarboe    9.344         2       0.2   1.8688
# 3   20-04-2022       Noel Staavos   11.200         7       0.0   4.8160
# 4   21-04-2022        Vivek Grady    8.940         3       0.0   2.4138
# 5   22-04-2022      Mark Hamilton   19.152         2       0.2   1.1970
# 6   23-04-2022    Brosina Hoffman    7.280         4       0.0   1.9656
# 7   24-04-2022       Edward Hooks   39.680         2       0.0  16.2688
# 8   25-04-2022         Dan Lawera    5.760         2       0.0   1.6704
# 9   26-04-2022    Andrew Gjertsen    4.448         2       0.2   0.3336
# 10  27-04-2022  Cassandra Brandow   34.650         3       0.0   9.7020
# 11  28-04-2022     Troy Blackwell  120.768         4       0.2   9.0576
# ...

# %%
df=pd.read_csv("Sales_short_data2.csv",header=None,prefix='X')
df
# Out:
#             X0                 X1       X2        X3        X4       X5
# 0        Dates      Customer Name    Sales  Quantity  Discount   Profit
# 1   17-04-2022         Anne Pryor    18.69         7         0   5.2332
# 2   18-04-2022        Mark Packer   140.75         5         0   42.225
# 3   19-04-2022      Ashley Jarboe    9.344         2       0.2   1.8688
# 4   20-04-2022       Noel Staavos     11.2         7         0    4.816
# 5   21-04-2022        Vivek Grady     8.94         3         0   2.4138
# 6   22-04-2022      Mark Hamilton   19.152         2       0.2    1.197
# 7   23-04-2022    Brosina Hoffman     7.28         4         0   1.9656
# 8   24-04-2022       Edward Hooks    39.68         2         0  16.2688
# 9   25-04-2022         Dan Lawera     5.76         2         0   1.6704
# 10  26-04-2022    Andrew Gjertsen    4.448         2       0.2   0.3336
# 11  27-04-2022  Cassandra Brandow    34.65         3         0    9.702
# ...

# %%
df=pd.read_csv("Sales_short_data2.csv",header=0,names=['date','customer','revanue','quantity','discount','profit'],prefix='XY_')
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-3d8316332428> in <module>
# ----> 1 df=pd.read_csv("Sales_short_data2.csv",header=0,names=['date','customer','revanue','quantity','discount','profit'],prefix='XY_')
#       2 df
#
# ...

# %%
df=pd.read_csv("Sales_short_data2.csv",header=0)
df
# Out:
#          Dates      Customer Name    Sales  Quantity  Discount   Profit
# 0   17-04-2022         Anne Pryor   18.690         7       0.0   5.2332
# 1   18-04-2022        Mark Packer  140.750         5       0.0  42.2250
# 2   19-04-2022      Ashley Jarboe    9.344         2       0.2   1.8688
# 3   20-04-2022       Noel Staavos   11.200         7       0.0   4.8160
# 4   21-04-2022        Vivek Grady    8.940         3       0.0   2.4138
# 5   22-04-2022      Mark Hamilton   19.152         2       0.2   1.1970
# 6   23-04-2022    Brosina Hoffman    7.280         4       0.0   1.9656
# 7   24-04-2022       Edward Hooks   39.680         2       0.0  16.2688
# 8   25-04-2022         Dan Lawera    5.760         2       0.0   1.6704
# 9   26-04-2022    Andrew Gjertsen    4.448         2       0.2   0.3336
# 10  27-04-2022  Cassandra Brandow   34.650         3       0.0   9.7020
# 11  28-04-2022     Troy Blackwell  120.768         4       0.2   9.0576
# ...

# %%
df=pd.read_csv("Sales_short_data2.csv",header=3)
df
# Out:
#    19-04-2022      Ashley Jarboe    9.344  2  0.2   1.8688
# 0  20-04-2022       Noel Staavos   11.200  7  0.0   4.8160
# 1  21-04-2022        Vivek Grady    8.940  3  0.0   2.4138
# 2  22-04-2022      Mark Hamilton   19.152  2  0.2   1.1970
# 3  23-04-2022    Brosina Hoffman    7.280  4  0.0   1.9656
# 4  24-04-2022       Edward Hooks   39.680  2  0.0  16.2688
# 5  25-04-2022         Dan Lawera    5.760  2  0.0   1.6704
# 6  26-04-2022    Andrew Gjertsen    4.448  2  0.2   0.3336
# 7  27-04-2022  Cassandra Brandow   34.650  3  0.0   9.7020
# 8  28-04-2022     Troy Blackwell  120.768  4  0.2   9.0576
# 9  29-04-2022   Cindy Schnelling   10.368  2  0.2   1.5552

# %%
df=pd.read_csv("Sales_short_data2.csv",index_col=0)
df
# Out:
#                 Customer Name    Sales  Quantity  Discount   Profit
# Dates
# 17-04-2022         Anne Pryor   18.690         7       0.0   5.2332
# 18-04-2022        Mark Packer  140.750         5       0.0  42.2250
# 19-04-2022      Ashley Jarboe    9.344         2       0.2   1.8688
# 20-04-2022       Noel Staavos   11.200         7       0.0   4.8160
# 21-04-2022        Vivek Grady    8.940         3       0.0   2.4138
# 22-04-2022      Mark Hamilton   19.152         2       0.2   1.1970
# 23-04-2022    Brosina Hoffman    7.280         4       0.0   1.9656
# 24-04-2022       Edward Hooks   39.680         2       0.0  16.2688
# 25-04-2022         Dan Lawera    5.760         2       0.0   1.6704
# 26-04-2022    Andrew Gjertsen    4.448         2       0.2   0.3336
# 27-04-2022  Cassandra Brandow   34.650         3       0.0   9.7020
# 28-04-2022     Troy Blackwell  120.768         4       0.2   9.0576
# 29-04-2022   Cindy Schnelling   10.368         2       0.2   1.5552

# %%
df=pd.read_csv("Sales_short_data2.csv",index_col='Customer Name')
df
# Out:
#                         Dates    Sales  Quantity  Discount   Profit
# Customer Name
# Anne Pryor         17-04-2022   18.690         7       0.0   5.2332
# Mark Packer        18-04-2022  140.750         5       0.0  42.2250
# Ashley Jarboe      19-04-2022    9.344         2       0.2   1.8688
# Noel Staavos       20-04-2022   11.200         7       0.0   4.8160
# Vivek Grady        21-04-2022    8.940         3       0.0   2.4138
# Mark Hamilton      22-04-2022   19.152         2       0.2   1.1970
# Brosina Hoffman    23-04-2022    7.280         4       0.0   1.9656
# Edward Hooks       24-04-2022   39.680         2       0.0  16.2688
# Dan Lawera         25-04-2022    5.760         2       0.0   1.6704
# Andrew Gjertsen    26-04-2022    4.448         2       0.2   0.3336
# Cassandra Brandow  27-04-2022   34.650         3       0.0   9.7020
# Troy Blackwell     28-04-2022  120.768         4       0.2   9.0576
# Cindy Schnelling   29-04-2022   10.368         2       0.2   1.5552

# %%
df=pd.read_csv("Sales_short_data2.csv",index_col=[0,3])
df
# Out:
#                          Customer Name    Sales  Discount   Profit
# Dates      Quantity
# 17-04-2022 7                Anne Pryor   18.690       0.0   5.2332
# 18-04-2022 5               Mark Packer  140.750       0.0  42.2250
# 19-04-2022 2             Ashley Jarboe    9.344       0.2   1.8688
# 20-04-2022 7              Noel Staavos   11.200       0.0   4.8160
# 21-04-2022 3               Vivek Grady    8.940       0.0   2.4138
# 22-04-2022 2             Mark Hamilton   19.152       0.2   1.1970
# 23-04-2022 4           Brosina Hoffman    7.280       0.0   1.9656
# 24-04-2022 2              Edward Hooks   39.680       0.0  16.2688
# 25-04-2022 2                Dan Lawera    5.760       0.0   1.6704
# 26-04-2022 2           Andrew Gjertsen    4.448       0.2   0.3336
# 27-04-2022 3         Cassandra Brandow   34.650       0.0   9.7020
# 28-04-2022 4            Troy Blackwell  120.768       0.2   9.0576
# 29-04-2022 2          Cindy Schnelling   10.368       0.2   1.5552

# %%
df=pd.read_csv("Sales_short_data2.csv",index_col=['Sales','Quantity'])
df
# Out:
#                        Dates      Customer Name  Discount   Profit
# Sales   Quantity
# 18.690  7         17-04-2022         Anne Pryor       0.0   5.2332
# 140.750 5         18-04-2022        Mark Packer       0.0  42.2250
# 9.344   2         19-04-2022      Ashley Jarboe       0.2   1.8688
# 11.200  7         20-04-2022       Noel Staavos       0.0   4.8160
# 8.940   3         21-04-2022        Vivek Grady       0.0   2.4138
# 19.152  2         22-04-2022      Mark Hamilton       0.2   1.1970
# 7.280   4         23-04-2022    Brosina Hoffman       0.0   1.9656
# 39.680  2         24-04-2022       Edward Hooks       0.0  16.2688
# 5.760   2         25-04-2022         Dan Lawera       0.0   1.6704
# 4.448   2         26-04-2022    Andrew Gjertsen       0.2   0.3336
# 34.650  3         27-04-2022  Cassandra Brandow       0.0   9.7020
# 120.768 4         28-04-2022     Troy Blackwell       0.2   9.0576
# 10.368  2         29-04-2022   Cindy Schnelling       0.2   1.5552

# %%
df=pd.read_csv("Sales_short_data2.csv",usecols=[0])
df
# Out:
#          Dates
# 0   17-04-2022
# 1   18-04-2022
# 2   19-04-2022
# 3   20-04-2022
# 4   21-04-2022
# 5   22-04-2022
# 6   23-04-2022
# 7   24-04-2022
# 8   25-04-2022
# 9   26-04-2022
# 10  27-04-2022
# 11  28-04-2022
# 12  29-04-2022

# %%
df=pd.read_csv("Sales_short_data2.csv",usecols=[0,2,4])
df
# Out:
#          Dates    Sales  Discount
# 0   17-04-2022   18.690       0.0
# 1   18-04-2022  140.750       0.0
# 2   19-04-2022    9.344       0.2
# 3   20-04-2022   11.200       0.0
# 4   21-04-2022    8.940       0.0
# 5   22-04-2022   19.152       0.2
# 6   23-04-2022    7.280       0.0
# 7   24-04-2022   39.680       0.0
# 8   25-04-2022    5.760       0.0
# 9   26-04-2022    4.448       0.2
# 10  27-04-2022   34.650       0.0
# 11  28-04-2022  120.768       0.2
# 12  29-04-2022   10.368       0.2

# %%
df=pd.read_csv("Sales_short_data2.csv",usecols=['Discount','Profit','Sales'])
df
# Out:
#       Sales  Discount   Profit
# 0    18.690       0.0   5.2332
# 1   140.750       0.0  42.2250
# 2     9.344       0.2   1.8688
# 3    11.200       0.0   4.8160
# 4     8.940       0.0   2.4138
# 5    19.152       0.2   1.1970
# 6     7.280       0.0   1.9656
# 7    39.680       0.0  16.2688
# 8     5.760       0.0   1.6704
# 9     4.448       0.2   0.3336
# 10   34.650       0.0   9.7020
# 11  120.768       0.2   9.0576
# 12   10.368       0.2   1.5552

# %%
df=pd.read_csv("Sales_short_data2.csv",usecols=['Discount','Profit','Sales'])[['Discount','Profit','Sales']]
df
# Out:
#     Discount   Profit    Sales
# 0        0.0   5.2332   18.690
# 1        0.0  42.2250  140.750
# 2        0.2   1.8688    9.344
# 3        0.0   4.8160   11.200
# 4        0.0   2.4138    8.940
# 5        0.2   1.1970   19.152
# 6        0.0   1.9656    7.280
# 7        0.0  16.2688   39.680
# 8        0.0   1.6704    5.760
# 9        0.2   0.3336    4.448
# 10       0.0   9.7020   34.650
# 11       0.2   9.0576  120.768
# 12       0.2   1.5552   10.368

# %%
df=pd.read_csv("Sales_short_data2.csv",usecols=[4,0,2])[[4,0,2]]
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-5af6f3df25cb> in <module>
# ----> 1 df=pd.read_csv("Sales_short_data2.csv",usecols=[4,0,2])[[4,0,2]]
#       2 df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
# ...

# %%
df=pd.read_csv("Sales_short_data2.csv",skiprows=2)
df
# Out:
#     18-04-2022        Mark Packer   140.75  5    0   42.225
# 0   19-04-2022      Ashley Jarboe    9.344  2  0.2   1.8688
# 1   20-04-2022       Noel Staavos   11.200  7  0.0   4.8160
# 2   21-04-2022        Vivek Grady    8.940  3  0.0   2.4138
# 3   22-04-2022      Mark Hamilton   19.152  2  0.2   1.1970
# 4   23-04-2022    Brosina Hoffman    7.280  4  0.0   1.9656
# 5   24-04-2022       Edward Hooks   39.680  2  0.0  16.2688
# 6   25-04-2022         Dan Lawera    5.760  2  0.0   1.6704
# 7   26-04-2022    Andrew Gjertsen    4.448  2  0.2   0.3336
# 8   27-04-2022  Cassandra Brandow   34.650  3  0.0   9.7020
# 9   28-04-2022     Troy Blackwell  120.768  4  0.2   9.0576
# 10  29-04-2022   Cindy Schnelling   10.368  2  0.2   1.5552

# %%
df=pd.read_csv("Sales_short_data2.csv",skiprows=[1,3,5])
df
# Out:
#         Dates      Customer Name    Sales  Quantity  Discount   Profit
# 0  18-04-2022        Mark Packer  140.750         5       0.0  42.2250
# 1  20-04-2022       Noel Staavos   11.200         7       0.0   4.8160
# 2  22-04-2022      Mark Hamilton   19.152         2       0.2   1.1970
# 3  23-04-2022    Brosina Hoffman    7.280         4       0.0   1.9656
# 4  24-04-2022       Edward Hooks   39.680         2       0.0  16.2688
# 5  25-04-2022         Dan Lawera    5.760         2       0.0   1.6704
# 6  26-04-2022    Andrew Gjertsen    4.448         2       0.2   0.3336
# 7  27-04-2022  Cassandra Brandow   34.650         3       0.0   9.7020
# 8  28-04-2022     Troy Blackwell  120.768         4       0.2   9.0576
# 9  29-04-2022   Cindy Schnelling   10.368         2       0.2   1.5552

# %%
df=pd.read_csv("Sales_short_data2.csv",skipfooter=1)
df
# Out:
# <ipython-input-91-3c88077ca75e>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   df=pd.read_csv("Sales_short_data2.csv",skipfooter=1)
#          Dates      Customer Name    Sales  Quantity  Discount   Profit
# 0   17-04-2022         Anne Pryor   18.690         7       0.0   5.2332
# 1   18-04-2022        Mark Packer  140.750         5       0.0  42.2250
# 2   19-04-2022      Ashley Jarboe    9.344         2       0.2   1.8688
# 3   20-04-2022       Noel Staavos   11.200         7       0.0   4.8160
# 4   21-04-2022        Vivek Grady    8.940         3       0.0   2.4138
# 5   22-04-2022      Mark Hamilton   19.152         2       0.2   1.1970
# 6   23-04-2022    Brosina Hoffman    7.280         4       0.0   1.9656
# 7   24-04-2022       Edward Hooks   39.680         2       0.0  16.2688
# 8   25-04-2022         Dan Lawera    5.760         2       0.0   1.6704
# ...

# %%
df=pd.read_csv("Sales_short_data2.csv",skipfooter=4,engine='python')
df
# Out:
#         Dates    Customer Name    Sales  Quantity  Discount   Profit
# 0  17-04-2022       Anne Pryor   18.690         7       0.0   5.2332
# 1  18-04-2022      Mark Packer  140.750         5       0.0  42.2250
# 2  19-04-2022    Ashley Jarboe    9.344         2       0.2   1.8688
# 3  20-04-2022     Noel Staavos   11.200         7       0.0   4.8160
# 4  21-04-2022      Vivek Grady    8.940         3       0.0   2.4138
# 5  22-04-2022    Mark Hamilton   19.152         2       0.2   1.1970
# 6  23-04-2022  Brosina Hoffman    7.280         4       0.0   1.9656
# 7  24-04-2022     Edward Hooks   39.680         2       0.0  16.2688
# 8  25-04-2022       Dan Lawera    5.760         2       0.0   1.6704

# %%
df=pd.read_csv("Sales_short_data2.csv",skipfooter=[1,3,5],engine='python')
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-f60f9d916ed4> in <module>
# ----> 1 df=pd.read_csv("Sales_short_data2.csv",skipfooter=[1,3,5],engine='python')
#       2 df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
# ...

# %%
df=pd.read_csv("Sales_short_data2.csv",skipinitialspace=True)                 #Skip spaces after delimiter
df
# Out:
#          Dates      Customer Name    Sales  Quantity  Discount   Profit
# 0   17-04-2022         Anne Pryor   18.690         7       0.0   5.2332
# 1   18-04-2022        Mark Packer  140.750         5       0.0  42.2250
# 2   19-04-2022      Ashley Jarboe    9.344         2       0.2   1.8688
# 3   20-04-2022       Noel Staavos   11.200         7       0.0   4.8160
# 4   21-04-2022        Vivek Grady    8.940         3       0.0   2.4138
# 5   22-04-2022      Mark Hamilton   19.152         2       0.2   1.1970
# 6   23-04-2022    Brosina Hoffman    7.280         4       0.0   1.9656
# 7   24-04-2022       Edward Hooks   39.680         2       0.0  16.2688
# 8   25-04-2022         Dan Lawera    5.760         2       0.0   1.6704
# 9   26-04-2022    Andrew Gjertsen    4.448         2       0.2   0.3336
# 10  27-04-2022  Cassandra Brandow   34.650         3       0.0   9.7020
# 11  28-04-2022     Troy Blackwell  120.768         4       0.2   9.0576
# ...

# %%
df=pd.read_csv("Sales_short_data2.csv",skip_blank_lines=False)        #If True, skip over blank lines rather than interpreting as NaN values.
df
# Out:
#          Dates      Customer Name    Sales  Quantity  Discount   Profit
# 0   17-04-2022         Anne Pryor   18.690         7       0.0   5.2332
# 1   18-04-2022        Mark Packer  140.750         5       0.0  42.2250
# 2   19-04-2022      Ashley Jarboe    9.344         2       0.2   1.8688
# 3   20-04-2022       Noel Staavos   11.200         7       0.0   4.8160
# 4   21-04-2022        Vivek Grady    8.940         3       0.0   2.4138
# 5   22-04-2022      Mark Hamilton   19.152         2       0.2   1.1970
# 6   23-04-2022    Brosina Hoffman    7.280         4       0.0   1.9656
# 7   24-04-2022       Edward Hooks   39.680         2       0.0  16.2688
# 8   25-04-2022         Dan Lawera    5.760         2       0.0   1.6704
# 9   26-04-2022    Andrew Gjertsen    4.448         2       0.2   0.3336
# 10  27-04-2022  Cassandra Brandow   34.650         3       0.0   9.7020
# 11  28-04-2022     Troy Blackwell  120.768         4       0.2   9.0576
# ...

# %%
print(type(df['Dates']))
print(type(df['Dates'][0]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'str'>

# %%
df=pd.read_csv("Sales_short_data2.csv",na_values=2)
df
# Out:
#          Dates      Customer Name    Sales  Quantity  Discount   Profit
# 0   17-04-2022         Anne Pryor   18.690       7.0       0.0   5.2332
# 1   18-04-2022        Mark Packer  140.750       5.0       0.0  42.2250
# 2   19-04-2022      Ashley Jarboe    9.344       NaN       0.2   1.8688
# 3   20-04-2022       Noel Staavos   11.200       7.0       0.0   4.8160
# 4   21-04-2022        Vivek Grady    8.940       3.0       0.0   2.4138
# 5   22-04-2022      Mark Hamilton   19.152       NaN       0.2   1.1970
# 6   23-04-2022    Brosina Hoffman    7.280       4.0       0.0   1.9656
# 7   24-04-2022       Edward Hooks   39.680       NaN       0.0  16.2688
# 8   25-04-2022         Dan Lawera    5.760       NaN       0.0   1.6704
# 9   26-04-2022    Andrew Gjertsen    4.448       NaN       0.2   0.3336
# 10  27-04-2022  Cassandra Brandow   34.650       3.0       0.0   9.7020
# 11  28-04-2022     Troy Blackwell  120.768       4.0       0.2   9.0576
# ...

# %%
df=pd.read_csv("Sales_short_data2.csv",na_values='Troy Blackwell')
df
# Out:
#          Dates      Customer Name    Sales  Quantity  Discount   Profit
# 0   17-04-2022         Anne Pryor   18.690         7       0.0   5.2332
# 1   18-04-2022        Mark Packer  140.750         5       0.0  42.2250
# 2   19-04-2022      Ashley Jarboe    9.344         2       0.2   1.8688
# 3   20-04-2022       Noel Staavos   11.200         7       0.0   4.8160
# 4   21-04-2022        Vivek Grady    8.940         3       0.0   2.4138
# 5   22-04-2022      Mark Hamilton   19.152         2       0.2   1.1970
# 6   23-04-2022    Brosina Hoffman    7.280         4       0.0   1.9656
# 7   24-04-2022       Edward Hooks   39.680         2       0.0  16.2688
# 8   25-04-2022         Dan Lawera    5.760         2       0.0   1.6704
# 9   26-04-2022    Andrew Gjertsen    4.448         2       0.2   0.3336
# 10  27-04-2022  Cassandra Brandow   34.650         3       0.0   9.7020
# 11  28-04-2022                NaN  120.768         4       0.2   9.0576
# ...

# %%
df1=pd.read_csv("Sales_short_data2.csv",na_values=[2,'22-04-2022','Troy Blackwell'])
df1
# Out:
#          Dates      Customer Name    Sales  Quantity  Discount   Profit
# 0   17-04-2022         Anne Pryor   18.690       7.0       0.0   5.2332
# 1   18-04-2022        Mark Packer  140.750       5.0       0.0  42.2250
# 2   19-04-2022      Ashley Jarboe    9.344       NaN       0.2   1.8688
# 3   20-04-2022       Noel Staavos   11.200       7.0       0.0   4.8160
# 4   21-04-2022        Vivek Grady    8.940       3.0       0.0   2.4138
# 5          NaN      Mark Hamilton   19.152       NaN       0.2   1.1970
# 6   23-04-2022    Brosina Hoffman    7.280       4.0       0.0   1.9656
# 7   24-04-2022       Edward Hooks   39.680       NaN       0.0  16.2688
# 8   25-04-2022         Dan Lawera    5.760       NaN       0.0   1.6704
# 9   26-04-2022    Andrew Gjertsen    4.448       NaN       0.2   0.3336
# 10  27-04-2022  Cassandra Brandow   34.650       3.0       0.0   9.7020
# 11  28-04-2022                NaN  120.768       4.0       0.2   9.0576
# ...

# %%
df1.to_csv("na_values.csv")

# %%
df=pd.read_csv("na_values.csv")
df
# Out:
#     Unnamed: 0       Dates      Customer Name    Sales  Quantity  Discount  \
# 0            0  17-04-2022         Anne Pryor   18.690       7.0       0.0
# 1            1  18-04-2022        Mark Packer  140.750       5.0       0.0
# 2            2  19-04-2022      Ashley Jarboe    9.344       NaN       0.2
# 3            3  20-04-2022       Noel Staavos   11.200       7.0       0.0
# 4            4  21-04-2022        Vivek Grady    8.940       3.0       0.0
# 5            5         NaN      Mark Hamilton   19.152       NaN       0.2
# 6            6  23-04-2022    Brosina Hoffman    7.280       4.0       0.0
# 7            7  24-04-2022       Edward Hooks   39.680       NaN       0.0
# 8            8  25-04-2022         Dan Lawera    5.760       NaN       0.0
# 9            9  26-04-2022    Andrew Gjertsen    4.448       NaN       0.2
# 10          10  27-04-2022  Cassandra Brandow   34.650       3.0       0.0
# ...

# %%
df=pd.read_csv("na_values.csv",index_col=[0])
df
# Out:
#          Dates      Customer Name    Sales  Quantity  Discount   Profit
# 0   17-04-2022         Anne Pryor   18.690       7.0       0.0   5.2332
# 1   18-04-2022        Mark Packer  140.750       5.0       0.0  42.2250
# 2   19-04-2022      Ashley Jarboe    9.344       NaN       0.2   1.8688
# 3   20-04-2022       Noel Staavos   11.200       7.0       0.0   4.8160
# 4   21-04-2022        Vivek Grady    8.940       3.0       0.0   2.4138
# 5          NaN      Mark Hamilton   19.152       NaN       0.2   1.1970
# 6   23-04-2022    Brosina Hoffman    7.280       4.0       0.0   1.9656
# 7   24-04-2022       Edward Hooks   39.680       NaN       0.0  16.2688
# 8   25-04-2022         Dan Lawera    5.760       NaN       0.0   1.6704
# 9   26-04-2022    Andrew Gjertsen    4.448       NaN       0.2   0.3336
# 10  27-04-2022  Cassandra Brandow   34.650       3.0       0.0   9.7020
# 11  28-04-2022                NaN  120.768       4.0       0.2   9.0576
# ...

# %%
df=pd.read_csv("na_values.csv",index_col=[0],na_filter=False)
df
# Out:
#          Dates      Customer Name    Sales Quantity  Discount   Profit
# 0   17-04-2022         Anne Pryor   18.690      7.0       0.0   5.2332
# 1   18-04-2022        Mark Packer  140.750      5.0       0.0  42.2250
# 2   19-04-2022      Ashley Jarboe    9.344                0.2   1.8688
# 3   20-04-2022       Noel Staavos   11.200      7.0       0.0   4.8160
# 4   21-04-2022        Vivek Grady    8.940      3.0       0.0   2.4138
# 5                   Mark Hamilton   19.152                0.2   1.1970
# 6   23-04-2022    Brosina Hoffman    7.280      4.0       0.0   1.9656
# 7   24-04-2022       Edward Hooks   39.680                0.0  16.2688
# 8   25-04-2022         Dan Lawera    5.760                0.0   1.6704
# 9   26-04-2022    Andrew Gjertsen    4.448                0.2   0.3336
# 10  27-04-2022  Cassandra Brandow   34.650      3.0       0.0   9.7020
# 11  28-04-2022                     120.768      4.0       0.2   9.0576
# ...

# %%
df=pd.read_csv("na_values.csv",index_col=[0],na_filter=True)
df
# Out:
#          Dates      Customer Name    Sales  Quantity  Discount   Profit
# 0   17-04-2022         Anne Pryor   18.690       7.0       0.0   5.2332
# 1   18-04-2022        Mark Packer  140.750       5.0       0.0  42.2250
# 2   19-04-2022      Ashley Jarboe    9.344       NaN       0.2   1.8688
# 3   20-04-2022       Noel Staavos   11.200       7.0       0.0   4.8160
# 4   21-04-2022        Vivek Grady    8.940       3.0       0.0   2.4138
# 5          NaN      Mark Hamilton   19.152       NaN       0.2   1.1970
# 6   23-04-2022    Brosina Hoffman    7.280       4.0       0.0   1.9656
# 7   24-04-2022       Edward Hooks   39.680       NaN       0.0  16.2688
# 8   25-04-2022         Dan Lawera    5.760       NaN       0.0   1.6704
# 9   26-04-2022    Andrew Gjertsen    4.448       NaN       0.2   0.3336
# 10  27-04-2022  Cassandra Brandow   34.650       3.0       0.0   9.7020
# 11  28-04-2022                NaN  120.768       4.0       0.2   9.0576
# ...

# %%
df=pd.read_csv("na_values.csv",index_col=[0],verbose=False)
df
# Out:
#          Dates      Customer Name    Sales  Quantity  Discount   Profit
# 0   17-04-2022         Anne Pryor   18.690       7.0       0.0   5.2332
# 1   18-04-2022        Mark Packer  140.750       5.0       0.0  42.2250
# 2   19-04-2022      Ashley Jarboe    9.344       NaN       0.2   1.8688
# 3   20-04-2022       Noel Staavos   11.200       7.0       0.0   4.8160
# 4   21-04-2022        Vivek Grady    8.940       3.0       0.0   2.4138
# 5          NaN      Mark Hamilton   19.152       NaN       0.2   1.1970
# 6   23-04-2022    Brosina Hoffman    7.280       4.0       0.0   1.9656
# 7   24-04-2022       Edward Hooks   39.680       NaN       0.0  16.2688
# 8   25-04-2022         Dan Lawera    5.760       NaN       0.0   1.6704
# 9   26-04-2022    Andrew Gjertsen    4.448       NaN       0.2   0.3336
# 10  27-04-2022  Cassandra Brandow   34.650       3.0       0.0   9.7020
# 11  28-04-2022                NaN  120.768       4.0       0.2   9.0576
# ...

# %%
df=pd.read_csv("na_values.csv",index_col=[0],verbose=True)
df
# Out:
# Tokenization took: 0.00 ms
# Type conversion took: 1.00 ms
# Parser memory cleanup took: 0.00 ms
#          Dates      Customer Name    Sales  Quantity  Discount   Profit
# 0   17-04-2022         Anne Pryor   18.690       7.0       0.0   5.2332
# 1   18-04-2022        Mark Packer  140.750       5.0       0.0  42.2250
# 2   19-04-2022      Ashley Jarboe    9.344       NaN       0.2   1.8688
# 3   20-04-2022       Noel Staavos   11.200       7.0       0.0   4.8160
# 4   21-04-2022        Vivek Grady    8.940       3.0       0.0   2.4138
# 5          NaN      Mark Hamilton   19.152       NaN       0.2   1.1970
# 6   23-04-2022    Brosina Hoffman    7.280       4.0       0.0   1.9656
# 7   24-04-2022       Edward Hooks   39.680       NaN       0.0  16.2688
# 8   25-04-2022         Dan Lawera    5.760       NaN       0.0   1.6704
# 9   26-04-2022    Andrew Gjertsen    4.448       NaN       0.2   0.3336
# 10  27-04-2022  Cassandra Brandow   34.650       3.0       0.0   9.7020
# ...

# %%
df=pd.read_csv("na_values.csv",index_col=[0],keep_default_na=False)
df
# Out:
#          Dates      Customer Name    Sales Quantity  Discount   Profit
# 0   17-04-2022         Anne Pryor   18.690      7.0       0.0   5.2332
# 1   18-04-2022        Mark Packer  140.750      5.0       0.0  42.2250
# 2   19-04-2022      Ashley Jarboe    9.344                0.2   1.8688
# 3   20-04-2022       Noel Staavos   11.200      7.0       0.0   4.8160
# 4   21-04-2022        Vivek Grady    8.940      3.0       0.0   2.4138
# 5                   Mark Hamilton   19.152                0.2   1.1970
# 6   23-04-2022    Brosina Hoffman    7.280      4.0       0.0   1.9656
# 7   24-04-2022       Edward Hooks   39.680                0.0  16.2688
# 8   25-04-2022         Dan Lawera    5.760                0.0   1.6704
# 9   26-04-2022    Andrew Gjertsen    4.448                0.2   0.3336
# 10  27-04-2022  Cassandra Brandow   34.650      3.0       0.0   9.7020
# 11  28-04-2022                     120.768      4.0       0.2   9.0576
# ...

# %%
df=pd.read_csv("na_values.csv",index_col=[0],keep_default_na=True)
df
# Out:
#          Dates      Customer Name    Sales  Quantity  Discount   Profit
# 0   17-04-2022         Anne Pryor   18.690       7.0       0.0   5.2332
# 1   18-04-2022        Mark Packer  140.750       5.0       0.0  42.2250
# 2   19-04-2022      Ashley Jarboe    9.344       NaN       0.2   1.8688
# 3   20-04-2022       Noel Staavos   11.200       7.0       0.0   4.8160
# 4   21-04-2022        Vivek Grady    8.940       3.0       0.0   2.4138
# 5          NaN      Mark Hamilton   19.152       NaN       0.2   1.1970
# 6   23-04-2022    Brosina Hoffman    7.280       4.0       0.0   1.9656
# 7   24-04-2022       Edward Hooks   39.680       NaN       0.0  16.2688
# 8   25-04-2022         Dan Lawera    5.760       NaN       0.0   1.6704
# 9   26-04-2022    Andrew Gjertsen    4.448       NaN       0.2   0.3336
# 10  27-04-2022  Cassandra Brandow   34.650       3.0       0.0   9.7020
# 11  28-04-2022                NaN  120.768       4.0       0.2   9.0576
# ...

# %%
df=pd.read_csv("Sales_short_data2.csv",false_values=['27-04-2022','7','9.7020','Dan Lawera'])  #Values to consider as False.
df
# Out:
#          Dates      Customer Name    Sales  Quantity  Discount   Profit
# 0   17-04-2022         Anne Pryor   18.690         7       0.0   5.2332
# 1   18-04-2022        Mark Packer  140.750         5       0.0  42.2250
# 2   19-04-2022      Ashley Jarboe    9.344         2       0.2   1.8688
# 3   20-04-2022       Noel Staavos   11.200         7       0.0   4.8160
# 4   21-04-2022        Vivek Grady    8.940         3       0.0   2.4138
# 5   22-04-2022      Mark Hamilton   19.152         2       0.2   1.1970
# 6   23-04-2022    Brosina Hoffman    7.280         4       0.0   1.9656
# 7   24-04-2022       Edward Hooks   39.680         2       0.0  16.2688
# 8   25-04-2022         Dan Lawera    5.760         2       0.0   1.6704
# 9   26-04-2022    Andrew Gjertsen    4.448         2       0.2   0.3336
# 10  27-04-2022  Cassandra Brandow   34.650         3       0.0   9.7020
# 11  28-04-2022     Troy Blackwell  120.768         4       0.2   9.0576
# ...

# %%
df=pd.read_csv("Sales_short_data2.csv",true_values=['27-04-2022','7','9.7020','Dan Lawera'])  #Values to consider as True.
df
# Out:
#          Dates      Customer Name    Sales  Quantity  Discount   Profit
# 0   17-04-2022         Anne Pryor   18.690         7       0.0   5.2332
# 1   18-04-2022        Mark Packer  140.750         5       0.0  42.2250
# 2   19-04-2022      Ashley Jarboe    9.344         2       0.2   1.8688
# 3   20-04-2022       Noel Staavos   11.200         7       0.0   4.8160
# 4   21-04-2022        Vivek Grady    8.940         3       0.0   2.4138
# 5   22-04-2022      Mark Hamilton   19.152         2       0.2   1.1970
# 6   23-04-2022    Brosina Hoffman    7.280         4       0.0   1.9656
# 7   24-04-2022       Edward Hooks   39.680         2       0.0  16.2688
# 8   25-04-2022         Dan Lawera    5.760         2       0.0   1.6704
# 9   26-04-2022    Andrew Gjertsen    4.448         2       0.2   0.3336
# 10  27-04-2022  Cassandra Brandow   34.650         3       0.0   9.7020
# 11  28-04-2022     Troy Blackwell  120.768         4       0.2   9.0576
# ...

# %%
df=pd.read_csv("Sales_short_data2.csv",header=[1,3,4])
df
# Out:
#    17-04-2022         Anne Pryor    18.69  7    0   5.2332
#    19-04-2022      Ashley Jarboe    9.344  2  0.2   1.8688
#    20-04-2022       Noel Staavos     11.2  7    0    4.816
# 0  21-04-2022        Vivek Grady    8.940  3  0.0   2.4138
# 1  22-04-2022      Mark Hamilton   19.152  2  0.2   1.1970
# 2  23-04-2022    Brosina Hoffman    7.280  4  0.0   1.9656
# 3  24-04-2022       Edward Hooks   39.680  2  0.0  16.2688
# 4  25-04-2022         Dan Lawera    5.760  2  0.0   1.6704
# 5  26-04-2022    Andrew Gjertsen    4.448  2  0.2   0.3336
# 6  27-04-2022  Cassandra Brandow   34.650  3  0.0   9.7020
# 7  28-04-2022     Troy Blackwell  120.768  4  0.2   9.0576
# 8  29-04-2022   Cindy Schnelling   10.368  2  0.2   1.5552
